# %%
# %pip install transformers scikit-learn datasets pytorchvideo evaluate torch ipywidgets tqdm 
# %pip install accelerate>={ACCELERATE_MIN_VERSION}
# Out:
# Requirement already satisfied: transformers in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (4.46.2)
# Requirement already satisfied: scikit-learn in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: datasets in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: pytorchvideo in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: evaluate in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (0.4.3)
# Requirement already satisfied: torch in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: ipywidgets in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: tqdm in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (4.67.0)
# Requirement already satisfied: pyyaml>=5.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: numpy>=1.17 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (2.1.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: filelock in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: aiohttp in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: pandas in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (18.0.0)
# Requirement already satisfied: multiprocess<0.70.17 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: fvcore>=0.1.4 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo) (0.1.5.post20221221)
# Requirement already satisfied: av in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo) (13.1.0)
# Requirement already satisfied: parameterized in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo) (0.9.0)
# Requirement already satisfied: iopath in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo) (0.1.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: networkx in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: triton==3.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: comm>=0.1.3 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: aiosignal>=1.1.2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: yacs>=0.1.6 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo) (0.1.8)
# Requirement already satisfied: termcolor>=1.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo) (2.5.0)
# Requirement already satisfied: Pillow in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo) (11.0.0)
# Requirement already satisfied: tabulate in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo) (0.9.0)
# Requirement already satisfied: portalocker in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from iopath->pytorchvideo) (2.10.1)
# Requirement already satisfied: exceptiongroup in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: decorator in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pexpect>4.3 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tzdata>=2022.7 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: six>=1.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: executing>=1.2.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# prompt: define all_video_file_paths which contain file path of all the videos in the directory /content/UCF101_subset

import os

all_video_file_paths = []
for root, _, files in os.walk("d1/Anomaly-detection-Dataset"):
    for file in files:
        if file.endswith((".mp4", ".avi")):  # Add other video extensions if needed
            all_video_file_paths.append(os.path.join(root, file))

# %%
all_video_file_paths
# Out:
# ['d1/Anomaly-detection-Dataset/train/Normal/Normal_Videos066_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos333_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos917_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos249_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos755_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos840_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos380_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos218_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos863_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos090_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos617_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos199_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos060_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos268_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos658_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos757_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos821_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos818_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos017_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos788_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos191_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos350_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos386_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos169_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos208_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos450_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos443_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos586_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos149_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos760_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos497_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos389_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos731_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos764_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos131_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos776_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos673_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos124_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos493_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos283_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos451_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos609_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos504_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos812_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos920_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos327_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos058_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos599_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos846_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos204_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos848_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos838_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos652_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos236_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos344_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos515_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos373_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos765_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos671_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos272_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos676_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos285_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos680_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos751_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos073_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos610_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos388_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos697_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos553_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos423_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos859_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos315_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos750_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos402_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos467_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos180_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos371_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos636_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos163_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos338_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos550_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos294_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos299_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos081_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos153_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos074_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos379_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos322_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos820_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos646_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos802_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos413_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos141_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos845_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos221_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos855_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos762_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos488_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos647_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos663_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos079_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos234_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos205_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos715_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos075_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos730_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos532_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos119_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos519_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos329_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos657_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos622_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos166_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos383_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos499_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos274_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos440_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos212_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos084_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos839_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos770_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos483_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos228_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos336_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos281_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos265_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos071_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos589_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos484_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos334_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos540_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos638_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos675_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos351_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos592_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos649_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos245_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos536_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos426_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos581_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos270_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos376_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos817_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos918_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos085_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos358_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos567_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos088_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos619_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos800_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos790_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos742_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos427_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos225_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos507_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos689_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos172_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos693_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos734_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos094_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos077_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos739_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos945_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos398_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos099_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos262_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos038_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos193_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos664_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos858_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos596_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos713_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos568_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos623_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos703_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos736_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos072_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos422_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos304_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos403_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos517_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos674_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos123_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos461_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos799_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos659_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos441_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos424_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos118_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos093_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos784_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos503_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos700_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos369_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos134_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos273_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos577_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos229_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos741_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos723_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos103_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos477_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos395_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos754_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos049_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos195_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos396_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos502_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos290_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos280_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos323_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos616_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos653_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos416_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos612_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos421_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos740_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos797_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos016_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos144_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos364_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos314_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos259_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos684_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos275_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos170_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos495_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos407_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos613_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos787_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos111_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos102_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos011_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos368_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos844_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos752_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos264_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos582_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos814_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos324_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos694_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos162_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos698_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos126_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos654_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos030_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos763_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos779_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos716_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos238_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos506_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos339_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos472_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos179_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos481_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos069_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos456_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos043_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos348_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos813_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos164_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos392_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos559_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos021_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos187_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos384_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos326_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos632_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos512_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos475_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos510_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos308_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos335_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos161_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos437_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos668_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos666_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos292_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos711_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos605_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos678_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos578_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos718_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos829_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos688_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos400_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos045_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos410_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos293_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos120_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos286_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos008_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos155_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos537_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos753_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos269_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos706_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos136_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos514_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos198_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos222_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos306_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos215_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos573_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos332_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos288_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos438_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos252_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos279_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos185_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos005_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos219_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos534_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos856_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos791_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos564_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos140_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos083_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos690_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos474_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos463_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos498_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos105_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos528_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos942_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos727_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos202_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos298_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos220_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos809_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos148_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos916_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos076_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos146_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos462_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos620_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos804_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos560_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos354_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos618_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos271_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos313_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos795_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos777_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos642_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos387_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos662_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos087_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos747_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos729_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos250_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos679_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos692_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos415_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos349_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos305_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos037_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos053_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos054_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos480_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos539_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos028_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos291_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos061_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos160_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos611_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos039_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos685_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos261_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos683_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos490_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos242_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos627_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos080_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos808_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos948_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos425_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos635_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos950_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos682_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos825_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos555_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos469_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos253_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos385_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos865_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos699_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos590_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos583_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos156_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos571_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos523_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos366_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos492_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos672_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos584_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos501_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos282_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos117_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos570_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos836_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos256_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos546_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos295_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos785_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos819_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos639_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos444_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos665_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos594_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos138_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos013_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos089_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos381_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos032_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos435_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos946_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos728_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos608_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos052_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos919_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos735_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos174_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos370_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos494_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos147_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos807_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos086_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos064_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos541_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos448_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos436_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos630_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos830_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos669_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos551_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos316_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos098_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos404_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos207_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos107_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos036_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos151_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos139_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos311_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos771_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos775_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos806_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos112_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos850_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos428_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos476_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos331_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos598_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos633_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos082_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos429_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos468_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos695_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos143_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos841_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos708_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos864_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos309_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos531_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos454_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos768_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos287_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos505_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos544_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos276_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos816_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos491_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos001_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos176_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos095_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos511_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos337_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos412_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos216_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos165_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos325_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos687_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos445_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos115_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos125_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos029_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos624_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos455_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos399_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos397_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos154_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos471_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos569_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos227_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos655_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos296_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos355_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos110_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos572_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos186_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos677_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos565_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos233_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos434_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos133_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos527_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos521_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos575_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos556_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos535_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos853_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos518_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos660_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos375_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos465_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos774_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos200_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos091_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos661_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos557_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos023_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos382_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos114_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos548_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos433_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos595_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos721_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos184_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos113_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos390_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos628_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos516_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos614_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos420_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos834_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos558_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos602_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos607_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos330_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos319_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos832_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos226_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos459_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos244_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos178_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos104_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos022_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos232_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos116_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos823_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos278_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos810_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos667_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos513_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos561_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos340_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos378_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos533_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos563_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos135_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos746_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos552_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos786_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos192_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos230_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos241_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos645_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos449_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos489_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos258_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos277_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos307_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos509_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos419_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos430_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos190_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos157_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos815_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos744_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos803_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos078_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos145_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos321_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos300_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos243_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos137_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos044_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos046_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos588_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos206_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos473_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos793_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos372_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos542_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos625_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos529_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos109_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos377_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos756_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos629_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos009_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos794_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos545_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos691_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos197_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos773_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos211_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos705_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos748_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos122_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos826_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos593_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos297_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos240_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos574_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos128_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos267_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos738_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos508_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos922_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos447_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos328_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos707_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos464_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos733_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Normal/Normal_Videos709_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson032_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents005_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism039_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting043_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting049_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery127_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing074_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents014_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary094_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery136_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary039_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents061_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing096_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson008_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents076_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents056_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery138_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing058_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery030_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents070_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault001_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting030_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting042_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault023_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse010_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting024_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting043_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest033_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery094_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse038_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting014_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest031_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault015_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault019_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary070_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson019_x264.mp4',
# ...
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse018_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting005_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest018_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting013_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing075_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary064_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents146_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse045_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest035_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery084_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting047_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing108_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents136_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery061_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism025_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest003_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting010_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting036_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting011_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery085_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary090_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting021_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion023_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest041_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery139_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest023_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault051_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary091_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse044_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents066_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism046_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting041_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse012_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest019_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault011_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery063_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing065_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse028_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing107_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing109_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting013_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing019_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents067_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse043_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson018_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism032_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting042_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion015_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing092_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse001_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery033_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents010_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing097_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary053_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion011_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest008_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary025_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents099_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery083_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson010_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing082_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents075_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery037_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery089_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents149_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism037_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery112_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing031_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery024_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing089_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting031_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents112_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting039_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting014_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting005_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents068_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents118_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing030_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary015_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse033_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery116_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson025_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery128_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary077_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion046_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents148_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism015_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson013_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson003_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery028_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary098_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents078_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents128_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism018_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery076_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents091_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing046_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting004_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault038_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents127_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery009_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting015_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery019_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest017_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting031_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing012_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents021_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion050_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents115_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault016_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents102_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary043_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary087_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery066_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery053_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting020_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing091_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest025_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery102_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting006_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery003_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism050_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault005_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary019_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting029_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault004_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism004_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion044_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion047_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents086_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents037_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault044_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest026_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents035_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting004_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary016_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery059_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary079_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery031_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting022_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary003_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest037_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents006_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism035_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents110_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion029_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary014_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents047_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse025_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents132_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting050_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary012_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery041_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary032_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing032_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery068_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents081_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson034_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson027_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery020_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents016_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing068_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting018_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents053_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting041_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary017_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting012_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest036_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery121_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary060_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism017_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery075_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest050_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing094_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Vandalism040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting035_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary035_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Burglary040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing049_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents103_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse049_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting024_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing079_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents122_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion009_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery062_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents109_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents114_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing113_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery047_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents033_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault039_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery078_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arson028_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shoplifting007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents088_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing072_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery142_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Explosion022_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents092_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents048_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting027_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Shooting040_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Robbery114_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Fighting007_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/RoadAccidents130_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Arrest051_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Abuse002_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Stealing070_x264.mp4',
#  'd1/Anomaly-detection-Dataset/train/Anomaly/Assault046_x264.mp4',
#  ...]

# %%
class_labels = sorted({str(path).split("/")[3] for path in all_video_file_paths})
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}

print(f"Unique classes: {list(label2id.keys())}.")
# Out:
# Unique classes: ['Anomaly', 'Normal'].

# %% [markdown]
# Instantiate a video classification model from a pretrained checkpoint and its associated image processor. The model's encoder comes with pre-trained parameters, and the classification head is randomly initialized. The image processor will come in handy when writing the preprocessing pipeline for our dataset.

# %%
import torch
from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification

# Check if GPU is available and set device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model and image processor
model_ckpt = "MCG-NJU/videomae-base"
image_processor = VideoMAEImageProcessor.from_pretrained(model_ckpt)
model = VideoMAEForVideoClassification.from_pretrained(
    model_ckpt,
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes=True,  # for fine-tuning on different number of labels
)

# Move model to the GPU
model.to(device)
# Out:
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# VideoMAEForVideoClassification(
#   (videomae): VideoMAEModel(
#     (embeddings): VideoMAEEmbeddings(
#       (patch_embeddings): VideoMAEPatchEmbeddings(
#         (projection): Conv3d(3, 768, kernel_size=(2, 16, 16), stride=(2, 16, 16))
#       )
#     )
#     (encoder): VideoMAEEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x VideoMAELayer(
#           (attention): VideoMAESdpaAttention(
#             (attention): VideoMAESdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=False)
#               (key): Linear(in_features=768, out_features=768, bias=False)
#               (value): Linear(in_features=768, out_features=768, bias=False)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): VideoMAESelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): VideoMAEIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): VideoMAEOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# While the model is loading, you might notice the following warning:
#
# ```bash
# Some weights of the model checkpoint at MCG-NJU/videomae-base were not used when initializing VideoMAEForVideoClassification: [..., 'decoder.decoder_layers.1.attention.output.dense.bias', 'decoder.decoder_layers.2.attention.attention.key.weight']
# - This IS expected if you are initializing VideoMAEForVideoClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VideoMAEForVideoClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ```
#
# The warning is telling us we are throwing away some weights (e.g. the weights and bias of the `classifier` layer) and randomly initializing some others (the weights and bias of a new `classifier` layer). This is expected in this case, because we are adding a new head for which we don't have pretrained weights, so the library warns us we should fine-tune this model before using it for inference, which is exactly what we are going to do.
#
# **Note** that [this checkpoint](https://huggingface.co/MCG-NJU/videomae-base-finetuned-kinetics) leads to better performance on this task as the checkpoint was obtained fine-tuning on a similar downstream task having considerable domain overlap. You can check out [this checkpoint](https://huggingface.co/sayakpaul/videomae-base-finetuned-kinetics-finetuned-ucf101-subset) which was obtained by fine-tuning `MCG-NJU/videomae-base-finetuned-kinetics`.

# %% [markdown]
# ## Prepare the datasets for training

# %% [markdown]
# For preprocessing the videos, you will leverage the [PyTorchVideo library](https://pytorchvideo.org/). Start by importing the dependencies we need.

# %%
# %pip install torchvision opencv-python
# Out:
# Requirement already satisfied: torchvision in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (0.20.1)
# Requirement already satisfied: opencv-python in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: torch==2.5.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: numpy in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (2.21.5)
# Requirement already satisfied: triton==3.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (3.1.0)
# Requirement already satisfied: jinja2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: fsspec in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: filelock in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (9.1.0.70)
# Requirement already satisfied: networkx in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from torch==2.5.1->torchvision) (11.6.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# prompt: no module named torchvision.transforms.functional_tensor'

import torchvision

# %%
# !pip install pytorchvideo==0.1.1
import pytorchvideo.data

from pytorchvideo.transforms import (
    ApplyTransformToKey,
    Normalize,
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample,
)

from torchvision.transforms import (
    Compose,
    Lambda,
    RandomCrop,
    RandomHorizontalFlip,
    Resize,
)
# Out:
# Requirement already satisfied: pytorchvideo==0.1.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: fvcore>=0.1.4 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo==0.1.1) (0.1.5.post20221221)
# Requirement already satisfied: av in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo==0.1.1) (13.1.0)
# Requirement already satisfied: parameterized in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo==0.1.1) (0.9.0)
# Requirement already satisfied: iopath in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from pytorchvideo==0.1.1) (0.1.10)
# Requirement already satisfied: numpy in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (2.1.3)
# Requirement already satisfied: yacs>=0.1.6 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (6.0.2)
# Requirement already satisfied: tqdm in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (4.67.0)
# Requirement already satisfied: termcolor>=1.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (2.5.0)
# Requirement already satisfied: Pillow in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (11.0.0)
# Requirement already satisfied: tabulate in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from fvcore>=0.1.4->pytorchvideo==0.1.1) (0.9.0)
# Requirement already satisfied: typing_extensions in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from iopath->pytorchvideo==0.1.1) (4.12.2)
# Requirement already satisfied: portalocker in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from iopath->pytorchvideo==0.1.1) (2.10.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# For the training dataset transformations, use a combination of uniform temporal subsampling, pixel normalization, random cropping, and random horizontal flipping. For the validation and evaluation dataset transformations, keep the same transformation chain except for random cropping and horizontal flipping. To learn more about the details of these transformations check out the [official documentation of PyTorchVideo](https://pytorchvideo.org).
#
# Use the `image_processor` associated with the pre-trained model to obtain the following information:
#
# * Image mean and standard deviation with which the video frame pixels will be normalized.
# * Spatial resolution to which the video frames will be resized.
#
# Start by defining some constants.

# %%
mean = image_processor.image_mean
std = image_processor.image_std
if "shortest_edge" in image_processor.size:
    height = width = image_processor.size["shortest_edge"]
else:
    height = image_processor.size["height"]
    width = image_processor.size["width"]
resize_to = (height, width)

num_frames_to_sample = model.config.num_frames
sample_rate = 4
fps = 30
clip_duration = num_frames_to_sample * sample_rate / fps

# %% [markdown]
# Now, define the dataset-specific transformations and the datasets respectively. Starting with the training set:

# %%
dataset_root_path = "d1/Anomaly-detection-Dataset"

# %%
train_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    RandomShortSideScale(min_size=256, max_size=320),
                    RandomCrop(resize_to),
                    RandomHorizontalFlip(p=0.5),
                ]
            ),
        ),
    ]
)

train_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "train"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("random", clip_duration),
    decode_audio=False,
    transform=train_transform,
)

# %% [markdown]
# The same sequence of workflow can be applied to the validation and evaluation sets:

# %%
val_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    Resize(resize_to),
                ]
            ),
        ),
    ]
)

val_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "val"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

test_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "test"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

# %% [markdown]
# **Note**: The above dataset pipelines are taken from the [official PyTorchVideo example](https://pytorchvideo.org/docs/tutorial_classification#dataset). We're using the [`pytorchvideo.data.Ucf101()`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.Ucf101) function because it's tailored for the UCF-101 dataset. Under the hood, it returns a [`pytorchvideo.data.labeled_video_dataset.LabeledVideoDataset`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.LabeledVideoDataset) object. `LabeledVideoDataset` class is the base class for all things video in the PyTorchVideo dataset. So, if you want to use a custom dataset not supported off-the-shelf by PyTorchVideo, you can extend the `LabeledVideoDataset` class accordingly. Refer to the `data` API [documentation to](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html) learn more. Also, if your dataset follows a similar structure (as shown above), then using the `pytorchvideo.data.Ucf101()` should work just fine.
#
# You can access the `num_videos` argument to know the number of videos in the dataset.

# %%
print(train_dataset.num_videos, val_dataset.num_videos, test_dataset.num_videos)
# Out:
# 1201 175 525

# %% [markdown]
# ## Visualize the preprocessed video for better debugging

# %%
import imageio
import numpy as np
from IPython.display import Image

def unnormalize_img(img):
    """Un-normalizes the image pixels."""
    img = (img * std) + mean
    img = (img * 255).astype("uint8")
    return img.clip(0, 255)

def create_gif(video_tensor, filename="sample.gif"):
    """Prepares a GIF from a video tensor.

    The video tensor is expected to have the following shape:
    (num_frames, num_channels, height, width).
    """
    frames = []
    for video_frame in video_tensor:
        frame_unnormalized = unnormalize_img(video_frame.permute(1, 2, 0).numpy())
        frames.append(frame_unnormalized)
    kargs = {"duration": 0.25}
    imageio.mimsave(filename, frames, "GIF", **kargs)
    return filename

def display_gif(video_tensor, gif_name="sample.gif"):
    """Prepares and displays a GIF from a video tensor."""
    video_tensor = video_tensor.permute(1, 0, 2, 3)
    gif_filename = create_gif(video_tensor, gif_name)
    return Image(filename=gif_filename)

sample_video = next(iter(train_dataset))
video_tensor = sample_video["video"]
display_gif(video_tensor)

# %%
# %pip install imageio
# Out:
# Requirement already satisfied: imageio in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (2.36.0)
# Requirement already satisfied: pillow>=8.3.2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from imageio) (11.0.0)
# Requirement already satisfied: numpy in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from imageio) (2.1.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/sample_gif.gif" alt="Person playing basketball"/>
# </div>

# %% [markdown]
# ## Train the model

# %% [markdown]
# Leverage [`Trainer`](https://huggingface.co/docs/transformers/main_classes/trainer) from  🤗 Transformers for training the model. To instantiate a `Trainer`, you need to define the training configuration and an evaluation metric. The most important is the [`TrainingArguments`](https://huggingface.co/transformers/main_classes/trainer.html#transformers.TrainingArguments), which is a class that contains all the attributes to configure the training. It requires an output folder name, which will be used to save the checkpoints of the model. It also helps sync all the information in the model repository on 🤗 Hub.
#
# Most of the training arguments are self-explanatory, but one that is quite important here is `remove_unused_columns=False`. This one will drop any features not used by the model's call function. By default it's `True` because usually it's ideal to drop unused feature columns, making it easier to unpack inputs into the model's call function. But, in this case, you need the unused features ('video' in particular) in order to create `pixel_values` (which is a mandatory key our model expects in its inputs).

# %%
# %pip install wandb python-dotenv
# Out:
# Collecting wandb
#   Using cached wandb-0.18.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Requirement already satisfied: requests<3,>=2.0.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: setuptools in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (65.5.0)
# Collecting sentry-sdk>=2.0.0
#   Using cached sentry_sdk-2.18.0-py2.py3-none-any.whl (317 kB)
# Collecting click!=8.0.0,>=7.1
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0
#   Using cached protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Requirement already satisfied: psutil>=5.0.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (6.1.0)
# Requirement already satisfied: pyyaml in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: platformdirs in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (4.3.6)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from wandb) (4.12.2)
# Collecting setproctitle
#   Using cached setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitpython!=3.1.29,>=1.0.0
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Requirement already satisfied: six>=1.4.0 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Requirement already satisfied: idna<4,>=2.5 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, protobuf, docker-pycreds, click, gitdb, gitpython, wandb
# Successfully installed click-8.1.7 docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 protobuf-5.28.3 sentry-sdk-2.18.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.18.6
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import wandb

# Replace with your actual W&B API key
API_KEY = "f7b65d8399dd6262084e166f128e83f97b568e6e"

# Log in to W&B with the API key
wandb.login(key=API_KEY,relogin=True)

# Project details
PROJECT = "Videomae-Anomaly-Normal-Classification"
MODEL_NAME = "Videomae"
DATASET = "UCF Anomaly Detection Dataset"

# Initialize W&B with an increased timeout
wandb.init(
    project=PROJECT,
    tags=[MODEL_NAME, DATASET],
    notes="model training",
    settings=wandb.Settings(init_timeout=300)  # Increase timeout to 300 seconds
)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.003333645180100575, max=1.0…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 15
#      12 DATASET = "UCF Anomaly Detection Dataset"
#      14 # Initialize W&B with an increased timeout
# ---> 15 wandb.init(
#      16     project=PROJECT,
#      17     tags=[MODEL_NAME, DATASET],
#      18     notes="model training",
#      19     settings=wandb.Settings(init_timeout=300)  # Increase timeout to 300 seconds
#      20 )
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:1256, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1254     wi = _WandbInit()
#    1255     wi.setup(kwargs)
# -> 1256     return wi.init()
#    1258 except KeyboardInterrupt as e:
#    1259     if logger is not None:
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:817, in _WandbInit.init(self)
#     814 logger.info(f"communicating run to backend with {timeout} second timeout")
#     816 run_init_handle = backend.interface.deliver_run(run)
# --> 817 result = run_init_handle.wait(
#     818     timeout=timeout,
#     819     on_progress=self._on_progress_init,
#     820     cancel=True,
#     821 )
#     822 if result:
#     823     run_result = result.run_result
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/lib/mailbox.py:279, in MailboxHandle.wait(self, timeout, on_probe, on_progress, release, cancel)
#     276     if self._interface._transport_keepalive_failed():
#     277         raise MailboxError("transport failed")
# --> 279 found, abandoned = self._slot._get_and_clear(timeout=wait_timeout)
#     280 if found:
#     281     # Always update progress to 100% when done
#     282     if on_progress and progress_handle and progress_sent:
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/lib/mailbox.py:126, in _MailboxSlot._get_and_clear(self, timeout)
#     124 def _get_and_clear(self, timeout: float) -> Tuple[Optional[pb.Result], bool]:
#     125     found = None
# --> 126     if self._wait(timeout=timeout):
#     127         with self._lock:
#     128             found = self._result
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/lib/mailbox.py:122, in _MailboxSlot._wait(self, timeout)
#     121 def _wait(self, timeout: float) -> bool:
# --> 122     return self._event.wait(timeout=timeout)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
from dotenv import load_dotenv
import os
env_path =  ".env"
load_dotenv(env_path)

import wandb
import os
wandb_key =  os.getenv("WANDB_API_KEY")
wandb.login(key=wandb_key)

PROJECT = "Videomae-Anomaly-Classification"
MODEL_NAME = "Videomae"
DATASET = "UCF Anomaly Detection Dataset"

wandb.init(project=PROJECT, # the project I am working on
           tags=[MODEL_NAME, DATASET],
           notes ="Fine tuning videomae for UCF Anomaly binary classification")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112139577097778, max=1.0…
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[58], line 16
#      13 MODEL_NAME = "Videomae"
#      14 DATASET = "UCF Anomaly Detection Dataset"
# ---> 16 wandb.init(project=PROJECT, # the project I am working on
#      17            tags=[MODEL_NAME, DATASET],
#      18            notes ="Fine tuning videomae for UCF Anomaly binary classification")
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:1270, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1266     logger.exception("error in wandb.init()", exc_info=e)
#    1268 # Need to build delay into this sentry capture because our exit hooks
#    1269 # mess with sentry's ability to send out errors before the program ends.
# -> 1270 wandb._sentry.reraise(e)
#    1271 raise AssertionError()
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/analytics/sentry.py:161, in Sentry.reraise(self, exc)
#     158 self.exception(exc)
#     159 # this will messily add this "reraise" function to the stack trace,
#     160 # but hopefully it's not too bad
# --> 161 raise exc.with_traceback(sys.exc_info()[2])
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:1256, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1254     wi = _WandbInit()
#    1255     wi.setup(kwargs)
# -> 1256     return wi.init()
#    1258 except KeyboardInterrupt as e:
#    1259     if logger is not None:
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:847, in _WandbInit.init(self)
#     845         backend.cleanup()
#     846         self.teardown()
# --> 847     raise error
#     849 assert run_result is not None  # for mypy
#     851 if not run_result.HasField("run"):
#
# CommError: Run initialization has timed out after 90.0 sec. Please try increasing the timeout with the `init_timeout` setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`.

# %%
batch_size = 5

# %%
from transformers import TrainingArguments, Trainer

model_name = model_ckpt.split("/")[-1]
new_model_name = f"{model_name}-finetuned-ucf101-subset"
num_epochs = 8

args = TrainingArguments(
    new_model_name,
    remove_unused_columns=False,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=True,
    max_steps=(train_dataset.num_videos // batch_size) * num_epochs,
    fp16=True,
    report_to="wandb"
)
# Out:
# /root/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# The dataset returned by `pytorchvideo.data.Ucf101()` doesn't implement the `__len__` method. As such, we must define `max_steps` when instantiating `TrainingArguments`.
#
# Next, you need to define a function to compute the metrics from the predictions, which will use the `metric` you'll load now. The only preprocessing you have to do is to take the argmax of our predicted logits:

# %%
import evaluate

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# **A note on evaluation**:
#
# In the [VideoMAE paper](https://arxiv.org/abs/2203.12602), the authors use the following evaluation strategy. They evaluate the model on several clips from test videos and apply different crops to those clips and report the aggregate score. However, in the interest of simplicity and brevity, we don't consider that in this tutorial.
#
# Also, define a `collate_fn`, which will be used to batch examples together. Each batch consists of 2 keys, namely `pixel_values` and `labels`.

# %%
import torch
def collate_fn(examples):
    # permute to (num_frames, num_channels, height, width)
    pixel_values = torch.stack(
        [example["video"].permute(1, 0, 2, 3) for example in examples]
    )
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %% [markdown]
# Then you just pass all of this along with the datasets to `Trainer`:

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)
# Out:
# /tmp/ipykernel_3147/3087471478.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# You might wonder why you passed along the `image_processor` as a tokenizer when you preprocessed the data already. This is only to make sure the image processor configuration file (stored as JSON) will also be uploaded to the repo on the Hub.
#
# Now fine-tune our model by calling the `train` method:

# %%
import torch

# %%
train_results = trainer.train()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112151611855046, max=1.0…
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 train_results = trainer.train()
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/trainer.py:2114, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2111 try:
#    2112     # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    2113     hf_hub_utils.disable_progress_bars()
# -> 2114     return inner_training_loop(
#    2115         args=args,
#    2116         resume_from_checkpoint=resume_from_checkpoint,
#    2117         trial=trial,
#    2118         ignore_keys_for_eval=ignore_keys_for_eval,
#    2119     )
#    2120 finally:
#    2121     hf_hub_utils.enable_progress_bars()
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/trainer.py:2382, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2380 model.zero_grad()
#    2381 grad_norm: Optional[float] = None
# -> 2382 self.control = self.callback_handler.on_train_begin(args, self.state, self.control)
#    2384 if args.eval_on_start:
#    2385     self._evaluate(trial, ignore_keys_for_eval, skip_scheduler=True)
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/trainer_callback.py:468, in CallbackHandler.on_train_begin(self, args, state, control)
#     466 def on_train_begin(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
#     467     control.should_training_stop = False
# --> 468     return self.call_event("on_train_begin", args, state, control)
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/trainer_callback.py:518, in CallbackHandler.call_event(self, event, args, state, control, **kwargs)
#     516 def call_event(self, event, args, state, control, **kwargs):
#     517     for callback in self.callbacks:
# --> 518         result = getattr(callback, event)(
#     519             args,
#     520             state,
#     521             control,
#     522             model=self.model,
#     523             processing_class=self.processing_class,
#     524             optimizer=self.optimizer,
#     525             lr_scheduler=self.lr_scheduler,
#     526             train_dataloader=self.train_dataloader,
#     527             eval_dataloader=self.eval_dataloader,
#     528             **kwargs,
#     529         )
#     530         # A Callback can skip the return of `control` if it doesn't change it.
#     531         if result is not None:
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/integrations/integration_utils.py:911, in WandbCallback.on_train_begin(self, args, state, control, model, **kwargs)
#     909     args.run_name = None
#     910 if not self._initialized:
# --> 911     self.setup(args, state, model, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/transformers/integrations/integration_utils.py:838, in WandbCallback.setup(self, args, state, model, **kwargs)
#     831         self._wandb.termwarn(
#     832             "The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was "
#     833             "not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.",
#     834             repeat=False,
#     835         )
#     837 if self._wandb.run is None:
# --> 838     self._wandb.init(
#     839         project=os.getenv("WANDB_PROJECT", "huggingface"),
#     840         **init_args,
#     841     )
#     842 # add config parameters (run may have been created manually)
#     843 self._wandb.config.update(combined_dict, allow_val_change=True)
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:1270, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1266     logger.exception("error in wandb.init()", exc_info=e)
#    1268 # Need to build delay into this sentry capture because our exit hooks
#    1269 # mess with sentry's ability to send out errors before the program ends.
# -> 1270 wandb._sentry.reraise(e)
#    1271 raise AssertionError()
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/analytics/sentry.py:161, in Sentry.reraise(self, exc)
#     158 self.exception(exc)
#     159 # this will messily add this "reraise" function to the stack trace,
#     160 # but hopefully it's not too bad
# --> 161 raise exc.with_traceback(sys.exc_info()[2])
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:1256, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1254     wi = _WandbInit()
#    1255     wi.setup(kwargs)
# -> 1256     return wi.init()
#    1258 except KeyboardInterrupt as e:
#    1259     if logger is not None:
#
# File ~/.pyenv/versions/3.10.12/envs/videomae/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:847, in _WandbInit.init(self)
#     845         backend.cleanup()
#     846         self.teardown()
# --> 847     raise error
#     849 assert run_result is not None  # for mypy
#     851 if not run_result.HasField("run"):
#
# CommError: Run initialization has timed out after 90.0 sec. Please try increasing the timeout with the `init_timeout` setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`.

# %% [markdown]
# Once training is completed, share your model to the Hub with the [push_to_hub()](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer.push_to_hub) method so everyone can use your model:

# %%
# prompt: i want the model's last report on accuracy

train_results

# %%
trainer.push_to_hub()

# %% [markdown]
# ## Inference

# %% [markdown]
# Great, now that you have fine-tuned a model, you can use it for inference!
#
# Load a video for inference:

# %%
sample_test_video = next(iter(test_dataset))

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/sample_gif_two.gif" alt="Teams playing basketball"/>
# </div>
#
# The simplest way to try out your fine-tuned model for inference is to use it in a [`pipeline`](https://huggingface.co/docs/transformers/main/en/main_classes/pipelines#transformers.VideoClassificationPipeline). Instantiate a `pipeline` for video classification with your model, and pass your video to it:

# %%
# prompt: huggging face login

from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import pipeline

video_cls = pipeline(model="skywalker290/videomae-base-finetuned-ucf101-subset")
video_cls("https://huggingface.co/datasets/sayakpaul/ucf101-subset/resolve/main/v_BasketballDunk_g14_c06.avi")
# Out:
# config.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/345M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/415 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'score': 0.9853178262710571, 'label': 'BalanceBeam'},
#  {'score': 0.006622056942433119, 'label': 'Archery'},
#  {'score': 0.0035426155664026737, 'label': 'BabyCrawling'},
#  {'score': 0.0025341834407299757, 'label': 'ApplyEyeMakeup'},
#  {'score': 0.001983288209885359, 'label': 'ApplyLipstick'}]

# %% [markdown]
# You can also manually replicate the results of the `pipeline` if you'd like.

# %%
def run_inference(model, video):
    # (num_frames, num_channels, height, width)
    perumuted_sample_test_video = video.permute(1, 0, 2, 3)
    inputs = {
        "pixel_values": perumuted_sample_test_video.unsqueeze(0),
        "labels": torch.tensor(
            [sample_test_video["label"]]
        ),  # this can be skipped if you don't have labels available.
    }

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    model = model.to(device)

    # forward pass
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    return logits

# %% [markdown]
# Now, pass your input to the model and return the `logits`:
#
# ```
# >>> logits = run_inference(trained_model, sample_test_video["video"])
# ```
#
# Decoding the `logits`, we get:

# %%
logits = run_inference(model, sample_test_video["video"])

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: Basketball
