# %%
# prompt: define all_video_file_paths which contain file path of all the videos in the directory /content/UCF101_subset

import os
all_video_file_paths = []
for root, _, files in os.walk("d2/Anomaly-Multiclass-Dataset"):
    for file in files:
        if file.endswith((".mp4", ".avi")):  # Add other video extensions if needed
            all_video_file_paths.append(os.path.join(root, file))

# %%
model_dataset = "vivit-d2"
dataset_root_path = "d2/Anomaly-Multiclass-Dataset"

# %%
all_video_file_paths
# Out:
# ['d2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery127_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery136_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery138_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery030_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery094_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery035_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery025_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery144_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery105_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery130_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery058_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery107_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery071_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery014_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery072_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery073_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery045_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery093_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery096_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery133_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery005_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery104_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery011_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery084_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery007_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery061_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery032_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery124_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery063_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery029_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery120_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery083_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery037_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery089_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery112_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery132_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery060_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery116_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery034_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery128_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery076_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery019_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery012_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery026_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery066_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery102_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery003_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery059_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery031_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery041_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery038_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery020_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery121_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery075_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery040_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery062_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery047_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery078_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery137_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery142_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery002_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery114_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery113_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery069_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery091_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery119_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery125_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery054_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery070_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery115_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery092_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery049_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery101_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery036_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery010_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery146_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery008_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery099_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery043_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery015_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery050_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery051_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery110_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery079_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery006_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery131_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery065_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery129_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery077_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery055_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery150_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery017_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery042_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery143_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery023_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery039_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery016_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery018_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery145_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery098_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Robbery/Robbery111_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism045_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism036_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism034_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism049_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism013_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism011_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism006_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism023_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism029_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism030_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism002_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism042_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism018_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism009_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism040_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism033_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism035_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism010_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism001_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism038_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism008_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism012_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism026_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism031_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism005_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism020_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism014_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism003_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism039_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism047_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Vandalism/Vandalism017_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson045_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson041_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson029_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson018_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson052_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson038_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson031_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson013_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson005_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson017_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson039_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson026_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson037_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson014_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson020_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson050_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson008_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson012_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson035_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson001_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson009_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson027_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson011_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson044_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson010_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson023_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson032_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson019_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson036_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson042_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Arson/Arson030_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting043_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting042_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting006_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting004_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting023_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting036_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting041_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting025_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting010_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting054_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting050_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting033_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting008_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting005_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting002_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting007_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting022_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting029_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting028_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting052_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting017_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting044_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting003_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting032_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting015_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting030_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting027_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting038_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting012_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting013_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Shooting/Shooting001_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse023_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse014_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse013_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse049_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse002_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse018_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse011_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse004_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse043_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse033_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse006_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse025_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse022_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse010_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse041_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse035_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse047_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse001_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse045_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse031_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse050_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse032_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse016_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse039_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse026_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse038_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse020_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse042_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse036_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse015_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/Abuse/Abuse029_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents005_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents014_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents076_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents056_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents070_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents138_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents150_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents027_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents012_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents039_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents011_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents094_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents139_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents143_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents009_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents106_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents013_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents129_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents151_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents117_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents024_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents050_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents146_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents007_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents141_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents004_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents026_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents044_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents073_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents067_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents046_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents084_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents099_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents149_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents112_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents068_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents118_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents144_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents078_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents128_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents127_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents115_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents018_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents093_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents102_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents111_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents087_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents086_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents037_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents006_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents047_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents132_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents028_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents081_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents016_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents022_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents057_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents103_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents059_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents109_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents114_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents088_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents092_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents048_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents125_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents113_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents131_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents085_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents096_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents043_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents055_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccidents063_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/train/RoadAccidents/RoadAccid
x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing113_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing004_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing095_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing016_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing021_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing063_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing009_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing008_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing047_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing061_x264.mp4',
#  'd2/Anomaly-Multiclass-Dataset/test/Stealing/Stealing042_x264.mp4']

# %%
class_labels = sorted({str(path).split("/")[3] for path in all_video_file_paths})
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}

print(f"Unique classes: {list(label2id.keys())}.")
# Out:
# Unique classes: ['Abuse', 'Arrest', 'Arson', 'Assault', 'Burglary', 'Explosion', 'Fighting', 'RoadAccidents', 'Robbery', 'Shooting', 'Shoplifting', 'Stealing', 'Vandalism'].

# %% [markdown]
# There are 10 unique classes. For each class, there are 30 videos in the training set.

# %% [markdown]
# ## Load a model to fine-tune

# %% [markdown]
# Instantiate a video classification model from a pretrained checkpoint and its associated image processor. The model's encoder comes with pre-trained parameters, and the classification head is randomly initialized. The image processor will come in handy when writing the preprocessing pipeline for our dataset.

# %%
from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from transformers import  VivitConfig,VivitForVideoClassification

import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_ckpt = "MCG-NJU/videomae-base"
image_processor = VideoMAEImageProcessor.from_pretrained(model_ckpt)


#model = TimesformerForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400",
#                                                          label2id=label2id,
#                                                          id2label=id2label,
#                                                          ignore_mismatched_sizes=True
#                                                          )
model = VivitForVideoClassification.from_pretrained(
    "google/vivit-b-16x2-kinetics400",
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes=True)
model.to(device)
# Out:
# Some weights of VivitForVideoClassification were not initialized from the model checkpoint at google/vivit-b-16x2-kinetics400 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([400, 768]) in the checkpoint and torch.Size([13, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([400]) in the checkpoint and torch.Size([13]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# VivitForVideoClassification(
#   (vivit): VivitModel(
#     (embeddings): VivitEmbeddings(
#       (patch_embeddings): VivitTubeletEmbeddings(
#         (projection): Conv3d(3, 768, kernel_size=(2, 16, 16), stride=(2, 16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): VivitEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x VivitLayer(
#           (attention): VivitSdpaAttention(
#             (attention): VivitSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): VivitSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): VivitIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_act_fn): FastGELUActivation()
#           )
#           (output): VivitOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=13, bias=True)
# )

# %% [markdown]
# While the model is loading, you might notice the following warning:
#
# ```bash
# Some weights of the model checkpoint at MCG-NJU/videomae-base were not used when initializing VideoMAEForVideoClassification: [..., 'decoder.decoder_layers.1.attention.output.dense.bias', 'decoder.decoder_layers.2.attention.attention.key.weight']
# - This IS expected if you are initializing VideoMAEForVideoClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VideoMAEForVideoClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ```
#
# The warning is telling us we are throwing away some weights (e.g. the weights and bias of the `classifier` layer) and randomly initializing some others (the weights and bias of a new `classifier` layer). This is expected in this case, because we are adding a new head for which we don't have pretrained weights, so the library warns us we should fine-tune this model before using it for inference, which is exactly what we are going to do.
#
# **Note** that [this checkpoint](https://huggingface.co/MCG-NJU/videomae-base-finetuned-kinetics) leads to better performance on this task as the checkpoint was obtained fine-tuning on a similar downstream task having considerable domain overlap. You can check out [this checkpoint](https://huggingface.co/sayakpaul/videomae-base-finetuned-kinetics-finetuned-ucf101-subset) which was obtained by fine-tuning `MCG-NJU/videomae-base-finetuned-kinetics`.

# %% [markdown]
# ## Prepare the datasets for training

# %%
# prompt: no module named torchvision.transforms.functional_tensor'

# %%
import pytorchvideo.data
import torchvision

from pytorchvideo.transforms import (
    ApplyTransformToKey,
    Normalize,
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample,
)

from torchvision.transforms import (
    Compose,
    Lambda,
    RandomCrop,
    RandomHorizontalFlip,
    Resize,
)

# %% [markdown]
# For the training dataset transformations, use a combination of uniform temporal subsampling, pixel normalization, random cropping, and random horizontal flipping. For the validation and evaluation dataset transformations, keep the same transformation chain except for random cropping and horizontal flipping. To learn more about the details of these transformations check out the [official documentation of PyTorchVideo](https://pytorchvideo.org).
#
# Use the `image_processor` associated with the pre-trained model to obtain the following information:
#
# * Image mean and standard deviation with which the video frame pixels will be normalized.
# * Spatial resolution to which the video frames will be resized.
#
# Start by defining some constants.

# %%
mean = image_processor.image_mean
std = image_processor.image_std
if "shortest_edge" in image_processor.size:
    height = width = image_processor.size["shortest_edge"]
else:
    height = image_processor.size["height"]
    width = image_processor.size["width"]
resize_to = (height, width)

num_frames_to_sample = model.config.num_frames
sample_rate = 4
fps = 30
clip_duration = num_frames_to_sample * sample_rate / fps

# %% [markdown]
# Now, define the dataset-specific transformations and the datasets respectively. Starting with the training set:

# %%
train_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    RandomShortSideScale(min_size=256, max_size=320),
                    RandomCrop(resize_to),
                    RandomHorizontalFlip(p=0.5),
                ]
            ),
        ),
    ]
)

train_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "train"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("random", clip_duration),
    decode_audio=False,
    transform=train_transform,
)

# %% [markdown]
# The same sequence of workflow can be applied to the validation and evaluation sets:

# %%
val_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    Resize(resize_to),
                ]
            ),
        ),
    ]
)

val_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "val"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

test_dataset = pytorchvideo.data.Ucf101(
    data_path=os.path.join(dataset_root_path, "test"),
    clip_sampler=pytorchvideo.data.make_clip_sampler("uniform", clip_duration),
    decode_audio=False,
    transform=val_transform,
)

# %% [markdown]
# **Note**: The above dataset pipelines are taken from the [official PyTorchVideo example](https://pytorchvideo.org/docs/tutorial_classification#dataset). We're using the [`pytorchvideo.data.Ucf101()`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.Ucf101) function because it's tailored for the UCF-101 dataset. Under the hood, it returns a [`pytorchvideo.data.labeled_video_dataset.LabeledVideoDataset`](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html#pytorchvideo.data.LabeledVideoDataset) object. `LabeledVideoDataset` class is the base class for all things video in the PyTorchVideo dataset. So, if you want to use a custom dataset not supported off-the-shelf by PyTorchVideo, you can extend the `LabeledVideoDataset` class accordingly. Refer to the `data` API [documentation to](https://pytorchvideo.readthedocs.io/en/latest/api/data/data.html) learn more. Also, if your dataset follows a similar structure (as shown above), then using the `pytorchvideo.data.Ucf101()` should work just fine.
#
# You can access the `num_videos` argument to know the number of videos in the dataset.

# %%
print(train_dataset.num_videos, val_dataset.num_videos, test_dataset.num_videos)
# Out:
# 665 95 190

# %% [markdown]
# ## Visualize the preprocessed video for better debugging

# %%
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (2.36.0)
# Requirement already satisfied: pillow>=8.3.2 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from imageio) (11.0.0)
# Requirement already satisfied: numpy in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from imageio) (2.1.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import imageio
import numpy as np
from IPython.display import Image

def unnormalize_img(img):
    """Un-normalizes the image pixels."""
    img = (img * std) + mean
    img = (img * 255).astype("uint8")
    return img.clip(0, 255)

def create_gif(video_tensor, filename="sample.gif"):
    """Prepares a GIF from a video tensor.

    The video tensor is expected to have the following shape:
    (num_frames, num_channels, height, width).
    """
    frames = []
    for video_frame in video_tensor:
        frame_unnormalized = unnormalize_img(video_frame.permute(1, 2, 0).numpy())
        frames.append(frame_unnormalized)
    kargs = {"duration": 0.25}
    imageio.mimsave(filename, frames, "GIF", **kargs)
    return filename

def display_gif(video_tensor, gif_name="sample.gif"):
    """Prepares and displays a GIF from a video tensor."""
    video_tensor = video_tensor.permute(1, 0, 2, 3)
    gif_filename = create_gif(video_tensor, gif_name)
    return Image(filename=gif_filename)

sample_video = next(iter(train_dataset))
video_tensor = sample_video["video"]
display_gif(video_tensor)

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/sample_gif.gif" alt="Person playing basketball"/>
# </div>

# %% [markdown]
# ## Train the model

# %% [markdown]
# Leverage [`Trainer`](https://huggingface.co/docs/transformers/main_classes/trainer) from  🤗 Transformers for training the model. To instantiate a `Trainer`, you need to define the training configuration and an evaluation metric. The most important is the [`TrainingArguments`](https://huggingface.co/transformers/main_classes/trainer.html#transformers.TrainingArguments), which is a class that contains all the attributes to configure the training. It requires an output folder name, which will be used to save the checkpoints of the model. It also helps sync all the information in the model repository on 🤗 Hub.
#
# Most of the training arguments are self-explanatory, but one that is quite important here is `remove_unused_columns=False`. This one will drop any features not used by the model's call function. By default it's `True` because usually it's ideal to drop unused feature columns, making it easier to unpack inputs into the model's call function. But, in this case, you need the unused features ('video' in particular) in order to create `pixel_values` (which is a mandatory key our model expects in its inputs).

# %%
import wandb

# Replace with your actual W&B API key
API_KEY = "f7b65d8399dd6262084e166f128e83f97b568e6e"

# Log in to W&B with the API key
wandb.login(key=API_KEY,relogin=True)

# Project details
PROJECT = "vivit-d2"
MODEL_NAME = "Vivit"
DATASET = "UCF Anomaly Multiclass Classification"

# Initialize W&B with an increased timeout
wandb.init(
    project=PROJECT,
    tags=[MODEL_NAME, DATASET],
    notes="model training"  # Increase timeout to 300 seconds
)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing last run (ID:3cekwiqp) before initializing another...
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▃▄▄▄█▇▆▆▆</td></tr><tr><td>eval/loss</td><td>█▅▃▄▄▁▄▂▅▄</td></tr><tr><td>eval/runtime</td><td>▂▂▂▃▃█▂▁▂▂</td></tr><tr><td>eval/samples_per_second</td><td>▇▇▇▆▅▁▇█▇▇</td></tr><tr><td>eval/steps_per_second</td><td>▇▇▇▆▅▁▇█▇▇</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/grad_norm</td><td>▃▆█▁▁▁▁▁▁▁▅▁▁▁▅▅▁▁▁▂▁▁▁▁▁▁▅▁▆▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▂▄▆█████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▄▄▄▄▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>▃▆▄▅▁▁▃▁▂▂▁▁▂▁▃▄█▂▁▂▂▃▂▁▁▂▁▂▁▁▁▃▄▁▁▁▁▁▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.74375</td></tr><tr><td>eval/loss</td><td>1.76941</td></tr><tr><td>eval/runtime</td><td>753.6832</td></tr><tr><td>eval/samples_per_second</td><td>9.025</td></tr><tr><td>eval/steps_per_second</td><td>9.025</td></tr><tr><td>total_flos</td><td>3.0770189127029883e+19</td></tr><tr><td>train/epoch</td><td>9.1</td></tr><tr><td>train/global_step</td><td>12010</td></tr><tr><td>train/grad_norm</td><td>0.00033</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0009</td></tr><tr><td>train_loss</td><td>0.52648</td></tr><tr><td>train_runtime</td><td>9942.3302</td></tr><tr><td>train_samples_per_second</td><td>1.208</td></tr><tr><td>train_steps_per_second</td><td>1.208</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">soft-pyramid-1</strong> at: <a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d1/runs/3cekwiqp' target="_blank">https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d1/runs/3cekwiqp</a><br/> View project at: <a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d1' target="_blank">https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241114_132948-3cekwiqp/logs</code>
# Successfully finished last run (ID:3cekwiqp). Initializing new run:<br/>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/workspace/ayush/Major01/wandb/run-20241114_163603-8t2azdlh</code>
# Syncing run <strong><a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2/runs/8t2azdlh' target="_blank">classic-deluge-1</a></strong> to <a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2' target="_blank">https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2</a>
#  View run at <a href='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2/runs/8t2azdlh' target="_blank">https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2/runs/8t2azdlh</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/anookinskywalker-jaypee-institute-of-information-technology/vivit-d2/runs/8t2azdlh?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# !pip install 'accelerate>={ACCELERATE_MIN_VERSION}'
# Out:
# Requirement already satisfied: accelerate>={ACCELERATE_MIN_VERSION} in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (24.2)
# Requirement already satisfied: safetensors>=0.4.3 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (0.4.5)
# Requirement already satisfied: pyyaml in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (0.26.2)
# Requirement already satisfied: psutil in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (6.1.0)
# Requirement already satisfied: torch>=1.10.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from accelerate>={ACCELERATE_MIN_VERSION}) (2.5.1)
# Requirement already satisfied: filelock in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.16.1)
# Requirement already satisfied: tqdm>=4.42.1 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (4.67.0)
# Requirement already satisfied: requests in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (2024.9.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (2.21.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.5.8)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (9.1.0.70)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (11.6.1.9)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (11.2.1.3)
# Requirement already satisfied: networkx in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.4.2)
# Requirement already satisfied: triton==3.1.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.1.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (10.3.5.147)
# Requirement already satisfied: sympy==1.13.1 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (1.13.1)
# Requirement already satisfied: jinja2 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.1.4)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.3.1.170)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>={ACCELERATE_MIN_VERSION}) (2024.8.30)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
batch_size = 1

# %%
from transformers import TrainingArguments, Trainer

model_name = model_ckpt.split("/")[-1]
new_model_name = f"VIVIT-d2"
num_epochs = 10

args = TrainingArguments(
    new_model_name,
    remove_unused_columns=False,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    warmup_ratio=0.1,
    logging_steps=10,
    eval_steps=1000,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=True,
    max_steps=(train_dataset.num_videos // batch_size) * num_epochs,
    fp16=True,
    report_to="wandb"
)
# Out:
# /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# The dataset returned by `pytorchvideo.data.Ucf101()` doesn't implement the `__len__` method. As such, we must define `max_steps` when instantiating `TrainingArguments`.
#
# Next, you need to define a function to compute the metrics from the predictions, which will use the `metric` you'll load now. The only preprocessing you have to do is to take the argmax of our predicted logits:

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: numpy>=1.19.5 in /root/.pyenv/versions/3.10.12/envs/timesformers/lib/python3.10/site-packages (from scikit-learn) (2.1.3)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.6.0
#   Using cached scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import evaluate

metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# **A note on evaluation**:
#
# In the [VideoMAE paper](https://arxiv.org/abs/2203.12602), the authors use the following evaluation strategy. They evaluate the model on several clips from test videos and apply different crops to those clips and report the aggregate score. However, in the interest of simplicity and brevity, we don't consider that in this tutorial.
#
# Also, define a `collate_fn`, which will be used to batch examples together. Each batch consists of 2 keys, namely `pixel_values` and `labels`.

# %%
def collate_fn(examples):
    # permute to (num_frames, num_channels, height, width)
    pixel_values = torch.stack(
        [example["video"].permute(1, 0, 2, 3) for example in examples]
    )
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %% [markdown]
# Then you just pass all of this along with the datasets to `Trainer`:

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)
# Out:
# /tmp/ipykernel_2221/3087471478.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# You might wonder why you passed along the `image_processor` as a tokenizer when you preprocessed the data already. This is only to make sure the image processor configuration file (stored as JSON) will also be uploaded to the repo on the Hub.
#
# Now fine-tune our model by calling the `train` method:

# %%
import torch

# %%
train_results = trainer.train()
# Out:
#     <div>
#
#       <progress value='250' max='6650' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 250/6650 00:39 < 16:52, 6.32 it/s, Epoch 0.04/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %% [markdown]
# Once training is completed, share your model to the Hub with the [push_to_hub()](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer.push_to_hub) method so everyone can use your model:

# %%
trainer.push_to_hub()
# Out:
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/skywalker290/Timesformers-d1/commit/095a843f5fd9ca85809678bdb3bdcc2269b24472', commit_message='End of training', commit_description='', oid='095a843f5fd9ca85809678bdb3bdcc2269b24472', pr_url=None, repo_url=RepoUrl('https://huggingface.co/skywalker290/Timesformers-d1', endpoint='https://huggingface.co', repo_type='model', repo_id='skywalker290/Timesformers-d1'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Inference

# %% [markdown]
# Great, now that you have fine-tuned a model, you can use it for inference!
#
# Load a video for inference:

# %%
sample_test_video = next(iter(test_dataset))

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/sample_gif_two.gif" alt="Teams playing basketball"/>
# </div>
#
# The simplest way to try out your fine-tuned model for inference is to use it in a [`pipeline`](https://huggingface.co/docs/transformers/main/en/main_classes/pipelines#transformers.VideoClassificationPipeline). Instantiate a `pipeline` for video classification with your model, and pass your video to it:

# %%
from transformers import pipeline

video_cls = pipeline(model="my_awesome_video_cls_model")
video_cls("https://huggingface.co/datasets/sayakpaul/ucf101-subset/resolve/main/v_BasketballDunk_g14_c06.avi")
# Out:
# [{'score': 0.9272987842559814, 'label': 'BasketballDunk'},
#  {'score': 0.017777055501937866, 'label': 'BabyCrawling'},
#  {'score': 0.01663011871278286, 'label': 'BalanceBeam'},
#  {'score': 0.009560945443809032, 'label': 'BandMarching'},
#  {'score': 0.0068979403004050255, 'label': 'BaseballPitch'}]

# %% [markdown]
# You can also manually replicate the results of the `pipeline` if you'd like.

# %%
def run_inference(model, video):
    # (num_frames, num_channels, height, width)
    perumuted_sample_test_video = video.permute(1, 0, 2, 3)
    inputs = {
        "pixel_values": perumuted_sample_test_video.unsqueeze(0),
        "labels": torch.tensor(
            [sample_test_video["label"]]
        ),  # this can be skipped if you don't have labels available.
    }

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    model = model.to(device)

    # forward pass
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    return logits

# %% [markdown]
# Now, pass your input to the model and return the `logits`:
#
# ```
# >>> logits = run_inference(trained_model, sample_test_video["video"])
# ```
#
# Decoding the `logits`, we get:

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# # Predicted class: BasketballDunk
